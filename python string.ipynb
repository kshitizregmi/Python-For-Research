# %% [markdown]
# # python strings

# %%
txt1 = 'hi' 

txt2 = "hi"

# %%
txt1 == txt2
# Out:
# True

# %%
txt = "hi 
my name is 
kshitiz"
# Out:
#   File "<ipython-input-4-640f1cff46b1>", line 1
#     txt = "hi
#               ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # multiline string : triple quote

# %%
txt = """hi
my name is kshitiz
"""

# %%
print(txt)
# Out:
# hi
# my name is kshitiz

# %%
type(txt)
# Out:
# str

# %%
txt = '''
hi my name is 
kshitiz
'''

# %%
print(txt)
# Out:
# hi my name is
# kshitiz

# %%
type(txt)
# Out:
# str

# %%
"He said, 'he is travelling.' "
# Out:
# "He said, 'he is travelling.' "

# %% [markdown]
# # Indexing

# %%
txt = "Hello world"

# %%
print(txt[1])
# Out:
# e

# %%
txt[0]
# Out:
# 'H'

# %%
txt[10]
# Out:
# 'd'

# %%
len(txt)
# Out:
# 11

# %%
txt = "Hello world"

# %%
len(txt)
# Out:
# 11

# %%
txt[10]
# Out:
# 'd'

# %%
# range(start, end , step)

# %%
list(range(5, 10, 1))
# Out:
# [5, 6, 7, 8, 9]

# %%
# for loop in

# %% [markdown]
# # for loop in python

# %%
for index in range(0, len(txt), 1):
    letter = txt[index]
    print("The index is = {} and the letter is {}".format(index, letter))
# Out:
# The index is = 0 and the letter is H
# The index is = 1 and the letter is e
# The index is = 2 and the letter is l
# The index is = 3 and the letter is l
# The index is = 4 and the letter is o
# The index is = 5 and the letter is
# The index is = 6 and the letter is w
# The index is = 7 and the letter is o
# The index is = 8 and the letter is r
# The index is = 9 and the letter is l
# The index is = 10 and the letter is d

# %%
s = "HELLO WORLD"
print(len(s))
# Out:
# 11

# %%
s[10]
# Out:
# 'D'

# %%
start = len(s) - 1
end = -1
step = -1

# %%
# list(range(start, end , step))

# %%
for index in range(start,end, step ):
    letter = s[index]
    print(letter)
# Out:
# D
# L
# R
# O
# W
#
# O
# L
# L
# E
# H

# %%
s = "aeyi"
start = 0
end = len(s)
step = 1
for index in range(start, end, step):
    letter = s[index]
    if letter == 'a' or letter =='e' or letter == 'i' or letter == 'o' or letter =='u':
        print("The letter {} is vowel".format(letter))

    else:
        print("The letter {} is consonant".format(letter))
# Out:
# The letter a is vowel
# The letter e is vowel
# The letter y is consonant
# The letter i is vowel

# %% [markdown]
# # CW: WAP to print vowels and consonant in given word

# %%
s = "Hi my name is kshitiz"
start = 0
end = len(s)
step = 1
for index in range(start, end, step):
    letter = s[index]
    if letter == 'a' or letter =='e' or letter == 'i' or letter == 'o' or letter =='u':
        print("The letter {} is vowel".format(letter))

    elif letter == " ":
        continue
        print("test")
    else:
        print("The letter {} is consonant".format(letter))
# Out:
# The letter H is consonant
# The letter i is vowel
# The letter m is consonant
# The letter y is consonant
# The letter n is consonant
# The letter a is vowel
# The letter m is consonant
# The letter e is vowel
# The letter i is vowel
# The letter s is consonant
# The letter k is consonant
# The letter s is consonant
# The letter h is consonant
# The letter i is vowel
# The letter t is consonant
# The letter i is vowel
# The letter z is consonant

# %%
s = "Hi my name is kshitiz"
start = 0
end = len(s)
step = 1
for index in range(start, end, step):
    letter = s[index]
    if letter == 'a' or letter =='e' or letter == 'i' or letter == 'o' or letter =='u':
        print("The letter {} is vowel".format(letter))

    elif letter == " ":
        break
        print("test")
    else:
        print("The letter {} is consonant".format(letter))
# Out:
# The letter H is consonant
# The letter i is vowel

# %%
s = "Hi my name is kshitiz"
start = 0
end = len(s)
step = 1
for index in range(start, end, step):
    letter = s[index]
    if letter == 'a' or letter =='e' or letter == 'i' or letter == 'o' or letter =='u':
        print("The letter {} is vowel".format(letter))

    elif letter == " ":
        continue
        print("test")
    else:
        print("The letter {} is consonant".format(letter))
# Out:
# The letter H is consonant
# The letter i is vowel
# The letter m is consonant
# The letter y is consonant
# The letter n is consonant
# The letter a is vowel
# The letter m is consonant
# The letter e is vowel
# The letter i is vowel
# The letter s is consonant
# The letter k is consonant
# The letter s is consonant
# The letter h is consonant
# The letter i is vowel
# The letter t is consonant
# The letter i is vowel
# The letter z is consonant

# %%
s = "Hi my name is kshitiz."

# %% [markdown]
# # slicing in python

# %%
s[0] # indexing
# Out:
# 'H'

# %%
s[0:2] # slicing
# Out:
# 'Hi'

# %%
s[5:]
# Out:
# ' name is kshitiz.'

# %%
s[:5]
# Out:
# 'Hi my'

# %%
s[3:7] # slicing gives substring
# Out:
# 'my n'

# %%
"hi" + " gm"
# Out:
# 'hi gm'

# %%
"hi" * 3
# Out:
# 'hihihi'

# %%
"hi" - "h"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-a6af350c4883> in <module>
# ----> 1 "hi" - "h"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
name = "k$hitiz"

# %%
name[1]
# Out:
# '$'

# %%
name[1] = "s" # python string are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-4deffbdb9d2d> in <module>
# ----> 1 name[1] = "s"
#
# TypeError: 'str' object does not support item assignment

# %%
name = "k$hitiz $$"
name = name.replace("$", "s")

# %%
name
# Out:
# 'kshitiz ss'

# %%
"Happy Dashain".replace("Happy", "Great")
# Out:
# 'Great Dashain'

# %%
"Happy Dashain".upper() # text normalization
# Out:
# 'HAPPY DASHAIN'

# %%
"Happy Dashain".lower()
# Out:
# 'happy dashain'

# %%
txt = "This, will split all words."

# %%
txt.split(",")
# Out:
# ['This', ' will split all words.']

# %%
type(txt.split())
# Out:
# list

# %%
txt = "This will split all words."
words = txt.split()

# %%
words
# Out:
# ['This', 'will', 'split', 'all', 'words.']

# %%
-len(words)
# Out:
# -5

# %%
words[-len(words)]
# Out:
# 'This'

# %%
words[0] # indexing in list
# Out:
# 'This'

# %%
last_index = len(words) - 1
words[last_index]
# Out:
# 'words.'

# %%
words[-1] # negative indexing in python list
# Out:
# 'words.'

# %%
words[-2]
# Out:
# 'all'

# %%
for i in range(len(words)):
    letter = words[i]
    print(letter)
# Out:
# This
# will
# split
# all
# words.
