# %%
num1 = 2.5
num2 = 0.36

# %%
tmp = num1

# %%
num1 = num2

# %%
num2 = tmp

# %%
print(num1)
# Out:
# 0.36

# %%
print(num2)
# Out:
# 2.5

# %%
a = 5 
b = 6

# %%
# assigning multiple values to multiple variable
a, b = 5, 6

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
b , a = a, b

# %%
a
# Out:
# 6

# %%
b
# Out:
# 5

# %%
12 % 5
# Out:
# 2

# %%
50 - 5*6
# Out:
# 20
