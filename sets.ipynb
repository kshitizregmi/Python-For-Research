# %%
A = {"apple", "mango", "banana", 88}

# %%
print(A) # unordered
# Out:
# {88, 'apple', 'mango', 'banana'}

# %%
A[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-782c0e2fe61c> in <module>
# ----> 1 A[0]
#
# TypeError: 'set' object is not subscriptable

# %%
A = {"apple", "mango", "banana", 88}
for item in A:
    print(item)
# Out:
# 88
# apple
# mango
# banana

# %%
A = {"apple", "banana", "cherry"}
B = {"google", "microsoft", "apple"}

# %%
A.intersection(B)
# Out:
# {'apple'}

# %%
B.union(A)
# Out:
# {'apple', 'banana', 'cherry', 'google', 'microsoft'}

# %%
A - B
# Out:
# {'banana', 'cherry'}

# %%
A.difference(B)
# Out:
# {'banana', 'cherry'}

# %%
x = None
type(x)
# Out:
# NoneType

# %%
# None is a data type of its own (NoneType) and only None can be None.

# %%
x = None

# %%
x is None
# Out:
# True

# %%
x is not float
# Out:
# True

# %%
if x == None: # avoid this
    print("x is none")
# Out:
# x is none

# %%
if x is None:
    print("x is none")
# Out:
# x is none
