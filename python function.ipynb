# %%
# a.py
a = 20

b = 8

c = a + b

print(c)
# Out:
# 28

# %%
# b.py
a = 20

b = 8

c = a + b

print(c)
# Out:
# 28

# %%
def add():
    a = 20
    b = 8
    c = a + b
    print(c)

# %%
add()
# Out:
# 28

# %%
add()
# Out:
# 28

# %%
add()
# Out:
# 28

# %%
def add(a, b): # a, b are arguments given by user
    c = a + b
    print(c)

# %%
add(7, 3)
# Out:
# 10

# %%
add(2,2)
# Out:
# 4

# %% [markdown]
# # write a program to add two numbers and square the total sum.

# %%
def add(a, b):
    c = a + b
    return c

# %%
total = add(6,3)

# %%
total
# Out:
# 9

# %%
total ** 2
# Out:
# 81

# %%
def greet(name, msg):
    print("Hello {}, {}".format(name, msg))

# %%
greet("Kshitiz", "Good Morning")
# Out:
# Hello Kshitiz, Good Morning

# %%
greet("Ram", "Good Morning")
# Out:
# Hello Ram, Good Morning

# %%
greet("Ram")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-be9390e4bdaa> in <module>
# ----> 1 greet("Ram")
#
# TypeError: greet() missing 1 required positional argument: 'msg'

# %% [markdown]
# # default argument in python function

# %%
def greet(name, msg = "Good Morning"):
    print("Hello {}, {}".format(name, msg))

# %%
greet("Ram")
# Out:
# Hello Ram, Good Morning

# %%
greet("Kshitiz", "Good Evening")
# Out:
# Hello Kshitiz, Good Evening
