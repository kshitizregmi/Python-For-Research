# %%
# create
# open
# read : one line read, paragraph, whole text
# write
# append
# close

# %%
# create a blank text file in linux or mac

# %%
# !touch news.txt

# %% [markdown]
# # open file

# %%
f = open('news.txt', 'r')

# %%
f.read()
# Out:
# 'In a first for the November elections, the Election Commission on Thursday wrote to the District Police Office, Rautahat to take action against Nepal, who is a candidate for the House of Representatives from Rautahat-1, as per the Election (Offence and Punishment) Act.\n\nNepal, during his election campaign on Wednesday, had assured his voters that they would get job opportunities abroad for free. The commission on Thursday morning sought a written clarification from Nepal. However, within hours it recommended the police for the action saying that its investigation found that there was no confusion that the statement was made by him.\n\n\nhttps://tkpo.st/3THXmhN'

# %%
f = open('news.txt', 'r')
f.readlines()
# Out:
# ['In a first for the November elections, the Election Commission on Thursday wrote to the District Police Office, Rautahat to take action against Nepal, who is a candidate for the House of Representatives from Rautahat-1, as per the Election (Offence and Punishment) Act.\n',
#  '\n',
#  'Nepal, during his election campaign on Wednesday, had assured his voters that they would get job opportunities abroad for free. The commission on Thursday morning sought a written clarification from Nepal. However, within hours it recommended the police for the action saying that its investigation found that there was no confusion that the statement was made by him.\n',
#  '\n',
#  '\n',
#  'https://tkpo.st/3THXmhN']

# %%
f = open('news.txt', 'r')
para_1 = f.readline()
f.close()

# %%
para_1
# Out:
# 'In a first for the November elections, the Election Commission on Thursday wrote to the District Police Office, Rautahat to take action against Nepal, who is a candidate for the House of Representatives from Rautahat-1, as per the Election (Offence and Punishment) Act.\n'

# %%
with open('news.txt', 'r') as f: # best approach
    content = f.read()

# %%
content
# Out:
# 'In a first for the November elections, the Election Commission on Thursday wrote to the District Police Office, Rautahat to take action against Nepal, who is a candidate for the House of Representatives from Rautahat-1, as per the Election (Offence and Punishment) Act.\n\nNepal, during his election campaign on Wednesday, had assured his voters that they would get job opportunities abroad for free. The commission on Thursday morning sought a written clarification from Nepal. However, within hours it recommended the police for the action saying that its investigation found that there was no confusion that the statement was made by him.\n\n\nhttps://tkpo.st/3THXmhN'

# %%
f = open('new.txt', 'r') # you cannot open a file that doesn't exist
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-7c03177bc54a> in <module>
# ----> 1 f = open('new.txt', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'new.txt'

# %% [markdown]
# # write

# %%
with open('new.txt', 'w') as f:
    f.write("This is a new file")

# %%
with open('new.txt', 'r') as f: # read file
    content = f.read()

content
# Out:
# 'This is a new file'

# %%
with open('new.txt', 'w') as f: # write in a file
    f.write("This is a another new  file")

# %%
with open('new.txt', 'r') as f: # read a file
    content = f.read()

content
# Out:
# 'This is a another new  file'

# %% [markdown]
# # mode = 'a'

# %%
with open('new.txt', 'a') as f:
    f.write("\nThis is append mode it doesnot replace file with new one")

# %%
with open('new.txt', 'r') as f: # best approach
    content = f.read()

content
# Out:
# 'This is a another new  file\nThis is append mode it doesnot replace file with new one'

# %%
with open('newfile.txt', 'a') as f: # if file is not present append creates a new file 
    f.write("\nThis is append mode it doesnot replace file with new one")

# %%
with open('newfile.txt', 'r') as f: 
    content = f.read()

content
# Out:
# '\nThis is append mode it doesnot replace file with new one'
