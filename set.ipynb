# %%
# set mutable data type
car = {'audi', 'bmw', 'tesla'}

# %%
car.add('mercedes')

# %%
car
# Out:
# {'audi', 'bmw', 'mercedes', 'tesla'}

# %%
car.remove('tesla')

# %%
car
# Out:
# {'audi', 'bmw', 'mercedes'}

# %%
car = {'audi', 'bmw', 'tesla'}

# %%
int(input("enter a number"))

# %%
list(car)
# Out:
# ['tesla', 'audi', 'bmw']

# %%
tuple(car)
# Out:
# ('tesla', 'audi', 'bmw')
