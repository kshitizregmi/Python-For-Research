# %%
print('Hello, world!')
print("Welcome to NRCC")
# Out:
# Hello, world!
# Welcome to NRCC

# %%
print("Hello, My name is Kshitiz Regmi")
# Out:
# Hello, My name is Kshitiz Regmi

# %%
# adds two number 
a = 50
b = 5
c = a + b
print(c)
# Out:
# 55

# %%
5 % 2
# Out:
# 1

# %%
9 ** 2
# Out:
# 81

# %%
2 ** 4
# Out:
# 16

# %%
# divide two number
15/2
# Out:
# 7.5

# %%
15//2 # floor division
# Out:
# 7

# %%
# divide two number 5/2

# %%
a = 22.3

# %%
24.95 - 9.98
# Out:
# 14.969999999999999

# %%
2 + 3 * 5
# Out:
# 17

# %%
2 - 3 + 4
# Out:
# 3

# %%
a = 20

# %%
False = 90
# Out:
#   File "<ipython-input-20-653b4f8e142d>", line 1
#     False = 90
#               ^
# SyntaxError: can't assign to keyword

# %%
false = 90

# %%
name$ = "kshitz"
# Out:
#   File "<ipython-input-23-a660cd4b549f>", line 1
#     name$ = "kshitz"
#         ^
# SyntaxError: invalid syntax

# %%
num9 = 50

# %%
my_name = "kshitiz"

# %%
a = 2
A = 88

# %%
a = 2
print('The value of a is {}'.format(a))
# Out:
# The value of a is 2

# %%
x = 11
# Out:
# 88

# %%
x = 45 # updating values in variable

# %%
print(x)
# Out:
# 45

# %%
x = 90

# %%
print(x)
# Out:
# 90

# %%
x = 60
print("Initially x was {}".format(x))
x = x + 0.5
print("Finally x is {}".format(x))
# Out:
# Initially x was 60
# Finally x is 60.5

# %%
x = 40
print("Initially x was {}".format(x))
x = 'hi'
print("Finally x is {}".format(x))
# Out:
# Initially x was 40
# Finally x is hi

# %%
# swap values between variables
num1 = 2.5
num2 = 0.36

# %%
num1 = num2

# %%
num1
# Out:
# 0.36
